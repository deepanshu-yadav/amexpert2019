# %%
# loading the data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
transaction_df = pd.read_csv('data/train_AUpWtIz/customer_transaction_data.csv')
item_df = pd.read_csv('data/train_AUpWtIz/item_data.csv' )
campaign_df = pd.read_csv('data/train_AUpWtIz/campaign_data.csv' )
main_df = pd.read_csv('data/train_AUpWtIz/train.csv' )
coupon_item_df = pd.read_csv('data/train_AUpWtIz/coupon_item_mapping.csv')
customer_details_df = pd.read_csv('data/train_AUpWtIz/customer_demographics.csv')

# %%
main_cust_camp = pd.merge(pd.merge( main_df , customer_details_df , on ='customer_id'  , how='left' ) , campaign_df , on='campaign_id' , how='left')
main_cust_camp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78369 entries, 0 to 78368
# Data columns (total 14 columns):
# id                   78369 non-null int64
# campaign_id          78369 non-null int64
# coupon_id            78369 non-null int64
# customer_id          78369 non-null int64
# redemption_status    78369 non-null int64
# age_range            43661 non-null object
# marital_status       25394 non-null object
# rented               43661 non-null float64
# family_size          43661 non-null object
# no_of_children       14056 non-null object
# income_bracket       43661 non-null float64
# campaign_type        78369 non-null object
# start_date           78369 non-null object
# end_date             78369 non-null object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 9.0+ MB

# %%
len(main_cust_camp['coupon_id'].unique())
# Out:
# 866

# %%
len(coupon_item_df['coupon_id'].unique())
# Out:
# 1116

# %%
main_cust_camp_coupon_item  =pd.merge(main_cust_camp , coupon_item_df , on='coupon_id' , how = 'left' )
main_cust_camp_coupon_item_df = pd.merge(main_cust_camp_coupon_item , item_df , on = 'item_id' , how= 'left' )

# %%
main_cust_camp_coupon_item.tail()
# Out:
#              id  campaign_id  coupon_id  customer_id  redemption_status  \
# 6420689  128595           13        681          623                  0
# 6420690  128595           13        681          623                  0
# 6420691  128595           13        681          623                  0
# 6420692  128595           13        681          623                  0
# 6420693  128595           13        681          623                  0
#
#         age_range marital_status  rented family_size no_of_children  \
# 6420689       NaN            NaN     NaN         NaN            NaN
# 6420690       NaN            NaN     NaN         NaN            NaN
# 6420691       NaN            NaN     NaN         NaN            NaN
# 6420692       NaN            NaN     NaN         NaN            NaN
# 6420693       NaN            NaN     NaN         NaN            NaN
#
#          income_bracket campaign_type start_date  end_date  item_id
# 6420689             NaN             X   19/05/13  05/07/13    16981
# 6420690             NaN             X   19/05/13  05/07/13    44676
# 6420691             NaN             X   19/05/13  05/07/13    38641
# 6420692             NaN             X   19/05/13  05/07/13    34285
# 6420693             NaN             X   19/05/13  05/07/13      990

# %%
res = main_cust_camp_coupon_item_df.set_index(['customer_id' , 'item_id']).join( transaction_df.set_index(['customer_id' , 'item_id']) )

# %%
res.head()
# Out:
#                          id  campaign_id  coupon_id  redemption_status  \
# customer_id item_id
# 1           48       102278           13         24                  0
#             51       102278           13         24                  0
#             54       102278           13         24                  0
#             60       102278           13         24                  0
#             74       102278           13         24                  0
#
#                     age_range marital_status  rented family_size  \
# customer_id item_id
# 1           48            70+        Married     0.0           2
#             51            70+        Married     0.0           2
#             54            70+        Married     0.0           2
#             60            70+        Married     0.0           2
#             74            70+        Married     0.0           2
#
#                     no_of_children  income_bracket  ... start_date  end_date  \
# customer_id item_id                                 ...
# 1           48                 NaN             4.0  ...   19/05/13  05/07/13
#             51                 NaN             4.0  ...   19/05/13  05/07/13
#             54                 NaN             4.0  ...   19/05/13  05/07/13
#             60                 NaN             4.0  ...   19/05/13  05/07/13
#             74                 NaN             4.0  ...   19/05/13  05/07/13
#
#                     brand  brand_type       category date quantity  \
# customer_id item_id
# 1           48         56       Local  Packaged Meat  NaN      NaN
#             51         56       Local        Seafood  NaN      NaN
#             54         56       Local        Seafood  NaN      NaN
#             60         56       Local  Packaged Meat  NaN      NaN
#             74         56       Local        Seafood  NaN      NaN
#
#                      selling_price  other_discount  coupon_discount
# customer_id item_id
# 1           48                 NaN             NaN              NaN
#             51                 NaN             NaN              NaN
#             54                 NaN             NaN              NaN
#             60                 NaN             NaN              NaN
#             74                 NaN             NaN              NaN
#
# [5 rows x 21 columns]

# %%
res.reset_index().to_csv('full_data.csv')

# %%
tran_unique = transaction_df.groupby(['customer_id' , 'item_id'])

# %%
main_unique = main_cust_camp_coupon_item.groupby(['customer_id' , 'item_id'])

# %%
main_unique.head()
# Out:
#              id  campaign_id  coupon_id  customer_id  redemption_status  \
# 0             1           13         27         1053                  0
# 1             1           13         27         1053                  0
# 2             1           13         27         1053                  0
# 3             1           13         27         1053                  0
# 4             1           13         27         1053                  0
# 5             1           13         27         1053                  0
# 6             1           13         27         1053                  0
# 7             1           13         27         1053                  0
# 8             1           13         27         1053                  0
# 9             1           13         27         1053                  0
# 10            1           13         27         1053                  0
# 11            1           13         27         1053                  0
# 12            1           13         27         1053                  0
# 13            1           13         27         1053                  0
# 14            1           13         27         1053                  0
# 15            1           13         27         1053                  0
# 16            1           13         27         1053                  0
# 17            1           13         27         1053                  0
# 18            1           13         27         1053                  0
# 19            1           13         27         1053                  0
# 20            1           13         27         1053                  0
# 21            1           13         27         1053                  0
# 22            1           13         27         1053                  0
# 23            1           13         27         1053                  0
# 24            1           13         27         1053                  0
# 25            1           13         27         1053                  0
# 26            1           13         27         1053                  0
# 27            1           13         27         1053                  0
# 28            1           13         27         1053                  0
# 29            1           13         27         1053                  0
# ...         ...          ...        ...          ...                ...
# 6420664  128595           13        681          623                  0
# 6420665  128595           13        681          623                  0
# 6420666  128595           13        681          623                  0
# 6420667  128595           13        681          623                  0
# 6420668  128595           13        681          623                  0
# 6420669  128595           13        681          623                  0
# 6420670  128595           13        681          623                  0
# 6420671  128595           13        681          623                  0
# 6420672  128595           13        681          623                  0
# 6420673  128595           13        681          623                  0
# 6420674  128595           13        681          623                  0
# 6420675  128595           13        681          623                  0
# 6420676  128595           13        681          623                  0
# 6420677  128595           13        681          623                  0
# 6420678  128595           13        681          623                  0
# 6420679  128595           13        681          623                  0
# 6420680  128595           13        681          623                  0
# 6420681  128595           13        681          623                  0
# 6420682  128595           13        681          623                  0
# 6420683  128595           13        681          623                  0
# 6420684  128595           13        681          623                  0
# 6420685  128595           13        681          623                  0
# 6420686  128595           13        681          623                  0
# 6420687  128595           13        681          623                  0
# 6420688  128595           13        681          623                  0
# 6420689  128595           13        681          623                  0
# 6420690  128595           13        681          623                  0
# 6420691  128595           13        681          623                  0
# 6420692  128595           13        681          623                  0
# 6420693  128595           13        681          623                  0
#
#         age_range marital_status  rented family_size no_of_children  \
# 0           46-55            NaN     0.0           1            NaN
# 1           46-55            NaN     0.0           1            NaN
# 2           46-55            NaN     0.0           1            NaN
# 3           46-55            NaN     0.0           1            NaN
# 4           46-55            NaN     0.0           1            NaN
# 5           46-55            NaN     0.0           1            NaN
# 6           46-55            NaN     0.0           1            NaN
# 7           46-55            NaN     0.0           1            NaN
# 8           46-55            NaN     0.0           1            NaN
# 9           46-55            NaN     0.0           1            NaN
# 10          46-55            NaN     0.0           1            NaN
# 11          46-55            NaN     0.0           1            NaN
# 12          46-55            NaN     0.0           1            NaN
# 13          46-55            NaN     0.0           1            NaN
# 14          46-55            NaN     0.0           1            NaN
# 15          46-55            NaN     0.0           1            NaN
# 16          46-55            NaN     0.0           1            NaN
# 17          46-55            NaN     0.0           1            NaN
# 18          46-55            NaN     0.0           1            NaN
# 19          46-55            NaN     0.0           1            NaN
# 20          46-55            NaN     0.0           1            NaN
# 21          46-55            NaN     0.0           1            NaN
# 22          46-55            NaN     0.0           1            NaN
# 23          46-55            NaN     0.0           1            NaN
# 24          46-55            NaN     0.0           1            NaN
# 25          46-55            NaN     0.0           1            NaN
# 26          46-55            NaN     0.0           1            NaN
# 27          46-55            NaN     0.0           1            NaN
# 28          46-55            NaN     0.0           1            NaN
# 29          46-55            NaN     0.0           1            NaN
# ...           ...            ...     ...         ...            ...
# 6420664       NaN            NaN     NaN         NaN            NaN
# 6420665       NaN            NaN     NaN         NaN            NaN
# 6420666       NaN            NaN     NaN         NaN            NaN
# 6420667       NaN            NaN     NaN         NaN            NaN
# 6420668       NaN            NaN     NaN         NaN            NaN
# 6420669       NaN            NaN     NaN         NaN            NaN
# 6420670       NaN            NaN     NaN         NaN            NaN
# 6420671       NaN            NaN     NaN         NaN            NaN
# 6420672       NaN            NaN     NaN         NaN            NaN
# 6420673       NaN            NaN     NaN         NaN            NaN
# 6420674       NaN            NaN     NaN         NaN            NaN
# 6420675       NaN            NaN     NaN         NaN            NaN
# 6420676       NaN            NaN     NaN         NaN            NaN
# 6420677       NaN            NaN     NaN         NaN            NaN
# 6420678       NaN            NaN     NaN         NaN            NaN
# 6420679       NaN            NaN     NaN         NaN            NaN
# 6420680       NaN            NaN     NaN         NaN            NaN
# 6420681       NaN            NaN     NaN         NaN            NaN
# 6420682       NaN            NaN     NaN         NaN            NaN
# 6420683       NaN            NaN     NaN         NaN            NaN
# 6420684       NaN            NaN     NaN         NaN            NaN
# 6420685       NaN            NaN     NaN         NaN            NaN
# 6420686       NaN            NaN     NaN         NaN            NaN
# 6420687       NaN            NaN     NaN         NaN            NaN
# 6420688       NaN            NaN     NaN         NaN            NaN
# 6420689       NaN            NaN     NaN         NaN            NaN
# 6420690       NaN            NaN     NaN         NaN            NaN
# 6420691       NaN            NaN     NaN         NaN            NaN
# 6420692       NaN            NaN     NaN         NaN            NaN
# 6420693       NaN            NaN     NaN         NaN            NaN
#
#          income_bracket campaign_type start_date  end_date  item_id
# 0                   5.0             X   19/05/13  05/07/13    24775
# 1                   5.0             X   19/05/13  05/07/13    14958
# 2                   5.0             X   19/05/13  05/07/13    40431
# 3                   5.0             X   19/05/13  05/07/13    20749
# 4                   5.0             X   19/05/13  05/07/13    56860
# 5                   5.0             X   19/05/13  05/07/13    58066
# 6                   5.0             X   19/05/13  05/07/13    56921
# 7                   5.0             X   19/05/13  05/07/13    56955
# 8                   5.0             X   19/05/13  05/07/13    58068
# 9                   5.0             X   19/05/13  05/07/13    56907
# 10                  5.0             X   19/05/13  05/07/13    56963
# 11                  5.0             X   19/05/13  05/07/13    63014
# 12                  5.0             X   19/05/13  05/07/13    58067
# 13                  5.0             X   19/05/13  05/07/13    56757
# 14                  5.0             X   19/05/13  05/07/13    39603
# 15                  5.0             X   19/05/13  05/07/13     7176
# 16                  5.0             X   19/05/13  05/07/13     1683
# 17                  5.0             X   19/05/13  05/07/13     1729
# 18                  5.0             X   19/05/13  05/07/13    37790
# 19                  5.0             X   19/05/13  05/07/13    35736
# 20                  5.0             X   19/05/13  05/07/13     8294
# 21                  5.0             X   19/05/13  05/07/13    16449
# 22                  5.0             X   19/05/13  05/07/13     1418
# 23                  5.0             X   19/05/13  05/07/13     7126
# 24                  5.0             X   19/05/13  05/07/13     1556
# 25                  5.0             X   19/05/13  05/07/13    39181
# 26                  5.0             X   19/05/13  05/07/13    16834
# 27                  5.0             X   19/05/13  05/07/13    13647
# 28                  5.0             X   19/05/13  05/07/13     1589
# 29                  5.0             X   19/05/13  05/07/13    38088
# ...                 ...           ...        ...       ...      ...
# 6420664             NaN             X   19/05/13  05/07/13    41802
# 6420665             NaN             X   19/05/13  05/07/13    28879
# 6420666             NaN             X   19/05/13  05/07/13    13290
# 6420667             NaN             X   19/05/13  05/07/13    16298
# 6420668             NaN             X   19/05/13  05/07/13    40280
# 6420669             NaN             X   19/05/13  05/07/13    35022
# 6420670             NaN             X   19/05/13  05/07/13    24258
# 6420671             NaN             X   19/05/13  05/07/13     2687
# 6420672             NaN             X   19/05/13  05/07/13    20922
# 6420673             NaN             X   19/05/13  05/07/13    45107
# 6420674             NaN             X   19/05/13  05/07/13    58552
# 6420675             NaN             X   19/05/13  05/07/13    45428
# 6420676             NaN             X   19/05/13  05/07/13     2447
# 6420677             NaN             X   19/05/13  05/07/13    73087
# 6420678             NaN             X   19/05/13  05/07/13    73021
# 6420679             NaN             X   19/05/13  05/07/13    58948
# 6420680             NaN             X   19/05/13  05/07/13     5595
# 6420681             NaN             X   19/05/13  05/07/13    73065
# 6420682             NaN             X   19/05/13  05/07/13    73235
# 6420683             NaN             X   19/05/13  05/07/13    33551
# 6420684             NaN             X   19/05/13  05/07/13    39080
# 6420685             NaN             X   19/05/13  05/07/13    20606
# 6420686             NaN             X   19/05/13  05/07/13    10749
# 6420687             NaN             X   19/05/13  05/07/13    18577
# 6420688             NaN             X   19/05/13  05/07/13      842
# 6420689             NaN             X   19/05/13  05/07/13    16981
# 6420690             NaN             X   19/05/13  05/07/13    44676
# 6420691             NaN             X   19/05/13  05/07/13    38641
# 6420692             NaN             X   19/05/13  05/07/13    34285
# 6420693             NaN             X   19/05/13  05/07/13      990
#
# [6420687 rows x 15 columns]

# %%
len(main_unique)

# %%
transaction_df_index = transaction_df.set_index( ['customer_id' , 'item_id'] ).index.unique()
main_index  = main_cust_camp_coupon_item.set_index( ['customer_id' , 'item_id'] ).index.unique()

# %%
result = main_index.intersection(transaction_df_index)

# %%
result.to_series()
# Out:
# customer_id  item_id
# 912          34277       (912, 34277)
# 586          9035         (586, 9035)
# 1504         9140        (1504, 9140)
# 1152         15987      (1152, 15987)
# 1449         37015      (1449, 37015)
# 194          8736         (194, 8736)
# 742          9890         (742, 9890)
# 460          28939       (460, 28939)
# 1524         34085      (1524, 34085)
# 911          49043       (911, 49043)
# 433          30832       (433, 30832)
# 912          28935       (912, 28935)
# 1324         67797      (1324, 67797)
# 898          27568       (898, 27568)
# 781          33634       (781, 33634)
# 140          36718       (140, 36718)
# 254          6048         (254, 6048)
# 85           59644        (85, 59644)
# 1408         6424        (1408, 6424)
# 817          14014       (817, 14014)
# 1463         31095      (1463, 31095)
# 703          27824       (703, 27824)
# 724          63168       (724, 63168)
# 416          5798         (416, 5798)
# 424          18323       (424, 18323)
# 1386         55960      (1386, 55960)
# 659          61388       (659, 61388)
# 757          6480         (757, 6480)
# 12           33820        (12, 33820)
# 706          46010       (706, 46010)
#                             ...
# 1419         46530      (1419, 46530)
# 262          11498       (262, 11498)
# 314          38742       (314, 38742)
# 40           58644        (40, 58644)
# 1012         27882      (1012, 27882)
# 274          35689       (274, 35689)
# 1142         12636      (1142, 12636)
# 1236         57330      (1236, 57330)
# 412          17081       (412, 17081)
# 683          30221       (683, 30221)
# 559          28657       (559, 28657)
# 1383         51477      (1383, 51477)
# 1485         36046      (1485, 36046)
# 699          13647       (699, 13647)
# 1303         5622        (1303, 5622)
# 413          35167       (413, 35167)
# 1033         13859      (1033, 13859)
# 1544         18485      (1544, 18485)
# 1192         59669      (1192, 59669)
# 1122         32032      (1122, 32032)
# 1004         16049      (1004, 16049)
# 49           46041        (49, 46041)
# 1473         27932      (1473, 27932)
# 609          27815       (609, 27815)
# 956          18753       (956, 18753)
# 381          19417       (381, 19417)
# 467          46284       (467, 46284)
# 367          9733         (367, 9733)
# 858          52051       (858, 52051)
# 184          4500         (184, 4500)
# Length: 68122, dtype: object

# %%
new_data_frame = transaction_df.set_index(result)
new_data_frame.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-bd91031a41eb> in <module>
# ----> 1 new_data_frame = transaction_df.set_index(result)
#       2 new_data_frame.head()
#
# ~/Documents/udacity_project_plagarism/workspace_udacity/lib/python3.5/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4196         index._cleanup()
#    4197
# -> 4198         frame.index = index
#    4199
#    4200         if not inplace:
#
# ~/Documents/udacity_project_plagarism/workspace_udacity/lib/python3.5/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/Documents/udacity_project_plagarism/workspace_udacity/lib/python3.5/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
#     640
#
# ~/Documents/udacity_project_plagarism/workspace_udacity/lib/python3.5/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 1324566 elements, new values have 68122 elements

# %%
new_transaction_df = transaction_df.set_index(  [ 'customer_id' , 'item_id' ] ) 
new_main_df = main_cust_camp_coupon_item.set_index( [  'customer_id' , 'item_id' ] )
#pd.DataFrame( transaction_df , index = trans_index )

# %%
new_transaction_df_index = new_transaction_df.index.unique()
new_main_df_index= new_main_df.index.unique()

# %%
campaign_sucess = new_main_df_index.isin(new_transaction_df_index)

# %%
required_tranactions = new_transaction_df_index.isin(new_main_df_index)

# %%
campaign_sucess

# %%
print(len(campaign_sucess) , len(required_tranactions))

# %%
main_table_modified = main_cust_camp_coupon_item.reindex(  [ 'customer_id' , 'item_id' ] )

# %%
transaction_table_modified = transaction_df.reindex( [ 'customer_id' , 'item_id' ] )

# %%
transaction_table_modified.head()

# %%
transaction_df.info()

# %%
print( type(transaction_table_index ) )

# %%
transaction_df.reindex(transaction_table_index)

# %%
transaction_df.head()

# %%
main_table_index = main_table_index.unique()

# %%
transaction_table_index = transaction_table_index.unique()

# %%
unique_main_table = main_cust_camp_coupon_item[main_table_index]
unique_transaction_table = transaction_df[transaction_table_index]

# %%
main_table_index.values[0]

# %%
sucessful_campaign = main_table_index.isin(transaction_table_index)

# %%
transaction_table_subset  = transaction_table_index.isin( main_table_index )

# %%
if transaction_table_subset.sum() == sucessful_campaign.sum():
    print('same')

# %%
res = pd.concat(main_cust_camp_coupon_item[sucessful_campaign] , transaction_df[transaction_table_subset] , axis =1)

# %%
transaction_table_subset.sum()

# %%
(sucessful_campaign.sum() )

# %%
intersection.sum()

# %%
intersection[0:10000]

# %%
success = pd.concat(main_cust_camp_coupon_item[intersection] )
